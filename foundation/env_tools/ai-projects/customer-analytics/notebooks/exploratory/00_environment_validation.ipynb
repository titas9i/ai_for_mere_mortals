# %% [markdown]
# My First Notebook

# %%
print("AI Development Environment Validation")
print("=" * 50)
# Out:
# AI Development Environment Validation
# ==================================================

# %%
try:
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    import sklearn
    import torch
    import sys
    
    print("✅ All core libraries imported successfully")
    
    # Test basic functionality
    df = pd.DataFrame({'test': [1, 2, 3]})
    arr = np.array([1, 2, 3])
    tensor = torch.tensor([1, 2, 3])
    
    print("✅ Basic operations working")
    
    # Check versions
    print("\nInstalled Versions:")
    print(f"Python: {sys.version}")
    print(f"Pandas: {pd.__version__}")
    print(f"NumPy: {np.__version__}")
    print(f"scikit-learn: {sklearn.__version__}")
    print(f"PyTorch: {torch.__version__}")
    
    # Test plotting
    plt.figure(figsize=(6, 4))
    plt.plot([1, 2, 3], [1, 4, 9])
    plt.title("Environment Test Plot")
    plt.show()
    
    print("✅ Environment validation complete!")
    print("Your AI development environment is ready for action! 🚀")
    
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("Please check your environment setup")
# Out:
# ✅ All core libraries imported successfully
# ✅ Basic operations working
#
# Installed Versions:
# Python: 3.10.18 | packaged by conda-forge | (main, Jun  4 2025, 14:46:00) [Clang 18.1.8 ]
# Pandas: 2.3.0
# NumPy: 2.2.6
# scikit-learn: 1.7.0
# PyTorch: 2.5.1
# ✅ Environment validation complete!
# Your AI development environment is ready for action! 🚀
